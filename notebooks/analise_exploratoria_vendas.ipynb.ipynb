# %% [markdown]
# # 📊 Análise Exploratória de Vendas
#
# Projeto de portfólio em Python com foco em análise exploratória de dados de vendas, utilizando Pandas para geração de insights de negócio.

# %% [markdown]
# import pandas as pd

# %%
dados = {
    "Produto": ["Notebook", "Mouse", "Teclado", "Monitor"],
    "Vendas": [10, 50, 30, 20],
    "Preco": [3500, 80, 150, 1200]
}

df = pd.DataFrame(dados)
df
# Out:
#     Produto  Vendas  Preco
# 0  Notebook      10   3500
# 1     Mouse      50     80
# 2   Teclado      30    150
# 3   Monitor      20   1200

# %%
df["Faturamento"] = df["Vendas"] * df["Preco"]

# %%
df
# Out:
#     Produto  Vendas  Preco  Faturamento
# 0  Notebook      10   3500        35000
# 1     Mouse      50     80         4000
# 2   Teclado      30    150         4500
# 3   Monitor      20   1200        24000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Produto  4 non-null      object
#  1   Vendas   4 non-null      int64
#  2   Preco    4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#           Vendas        Preco
# count   4.000000     4.000000
# mean   27.500000  1232.500000
# std    17.078251  1596.107244
# min    10.000000    80.000000
# 25%    17.500000   132.500000
# 50%    25.000000   675.000000
# 75%    35.000000  1775.000000
# max    50.000000  3500.000000

# %%
df["Faturamento"] = df["Vendas"] * df["Preco"]

# %%
df
# Out:
#     Produto  Vendas  Preco  Faturamento
# 0  Notebook      10   3500        35000
# 1     Mouse      50     80         4000
# 2   Teclado      30    150         4500
# 3   Monitor      20   1200        24000

# %%
df.sort_values(by="Faturamento", ascending=False)
# Out:
#     Produto  Vendas  Preco  Faturamento
# 0  Notebook      10   3500        35000
# 3   Monitor      20   1200        24000
# 2   Teclado      30    150         4500
# 1     Mouse      50     80         4000

# %%
df["Faturamento"].sum()
# Out:
# np.int64(67500)

# %%
df.sort_values(by="Vendas", ascending=False)
# Out:
#     Produto  Vendas  Preco  Faturamento
# 1     Mouse      50     80         4000
# 2   Teclado      30    150         4500
# 3   Monitor      20   1200        24000
# 0  Notebook      10   3500        35000

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.bar(df["Produto"], df["Faturamento"])
plt.title("Faturamento por Produto")
plt.xlabel("Produto")
plt.ylabel("Faturamento")

plt.tight_layout()
plt.savefig("../images/faturamento_por_produto.png")
plt.show()
